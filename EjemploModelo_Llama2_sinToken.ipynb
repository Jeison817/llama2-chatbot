# %%
# !pip install transformers accelerate torch sentencepiece

# %%
from huggingface_hub import login

# Pega tu token de HuggingFace aquí
# Obtenerlo en: https://huggingface.co/settings/tokens
login(token=" --> token aqui <-- ")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_id = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=True)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    dtype=torch.float16,
    device_map="auto",
    token=True
)
print("✅ Modelo cargado correctamente")
# Out:
# ✅ Modelo cargado correctamente

# %%
def preguntar(texto):
    prompt = f"<s>[INST] {texto} [/INST]"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    output = model.generate(**inputs, max_new_tokens=150)
    respuesta = tokenizer.decode(output[0], skip_special_tokens=True)
    return respuesta.split("[/INST]")[-1].strip()

print(preguntar("¿Qué es la inteligencia artificial en 10 líneas?"))
# Out:
# ¡Claro! Aquí te presento una respuesta breve y concisa sobre la inteligencia artificial en 10 líneas:
#
# 1. La inteligencia artificial (IA) es el campo de la informática que se enfoca en crear sistemas capaces de realizar tareas que normalmente requieren inteligencia humana, como aprendizaje, razonamiento y toma de decisiones.
